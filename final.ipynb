# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import DateType
from pyspark.sql.functions import to_date
import matplotlib.pyplot as plt
from pyspark.ml.feature import StringIndexer

# %%
spark = SparkSession.builder.appName("cabai").getOrCreate()

# %%
data = spark.read.csv('cabai.csv', inferSchema=True, header=True)

# %%
# Mendapatkan jumlah baris dalam DataFrame
num_rows = data.count()
print("Jumlah baris dalam DataFrame:", num_rows)

# Mendapatkan daftar nama kolom
column_names = data.columns
print("Nama kolom dalam DataFrame:", column_names)
# Out:
# Jumlah baris dalam DataFrame: 1410
# Nama kolom dalam DataFrame: ['Tanggal', 'DKI Jakarta', 'pasar glodok', 'pasar senen', 'pasar Minggu', 'Pasar kramat jati', 'pasar Sunter Podomoro']

# %%
data.show()
# Out:
# +-----------+-----------+------------+-----------+------------+-----------------+---------------------+
# |    Tanggal|DKI Jakarta|pasar glodok|pasar senen|pasar Minggu|Pasar kramat jati|pasar Sunter Podomoro|
# +-----------+-----------+------------+-----------+------------+-----------------+---------------------+
# | 1 Jan 2020|      34809|       40000|      35000|       30000|            40000|                40000|
# | 2 Jan 2020|      34809|       40000|      35000|       30000|            40000|                40000|
# | 3 Jan 2020|      34957|       40000|      35000|       30000|            40000|                40000|
# | 4 Jan 2020|      36234|       40000|      30000|       30000|            55000|                40000|
# | 5 Jan 2020|      37340|       40000|      30000|       32000|            55000|                40000|
# | 6 Jan 2020|      38574|       50000|      30000|       35000|            40000|                50000|
# ...

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, DoubleType, DateType

# Skema DataFrame
schema = StructType([
    StructField("Tanggal", DateType(), True),
    StructField("DKI Jakarta", DoubleType(), True),
    StructField("pasar glodok", DoubleType(), True),
    StructField("pasar senen", DoubleType(), True),
    StructField("pasar Minggu", DoubleType(), True),
    StructField("Pasar kramat jati", DoubleType(), True),
    StructField("pasar Sunter Podomoro", DoubleType(), True),
    
])

# %%
#menampilkan hasil perubahan
data.printSchema()
# Out:
# root
#  |-- Tanggal: string (nullable = true)
#  |-- DKI Jakarta: integer (nullable = true)
#  |-- pasar glodok: integer (nullable = true)
#  |-- pasar senen: integer (nullable = true)
#  |-- pasar Minggu: integer (nullable = true)
#  |-- Pasar kramat jati: integer (nullable = true)
#  |-- pasar Sunter Podomoro: integer (nullable = true)

# %%
from pyspark.sql.functions import to_date
from pyspark.sql.types import DateType

# Ubah kolom Tanggal ke tipe data date
data = data.withColumn("Tanggal", to_date("Tanggal", "d MMM yyyy").cast(DateType()))

# %%
#menampilkan hasil perubahan
data.printSchema()
# Out:
# root
#  |-- Tanggal: date (nullable = true)
#  |-- DKI Jakarta: integer (nullable = true)
#  |-- pasar glodok: integer (nullable = true)
#  |-- pasar senen: integer (nullable = true)
#  |-- pasar Minggu: integer (nullable = true)
#  |-- Pasar kramat jati: integer (nullable = true)
#  |-- pasar Sunter Podomoro: integer (nullable = true)

# %%
import seaborn as sns

# %%
# Ambil data ke dalam Pandas DataFrame
data_pandas = data.toPandas()

# Plot menggunakan matplotlib dan seaborn
plt.figure(figsize=(12, 6))
plt.plot(data_pandas['Tanggal'], data_pandas['DKI Jakarta'], label='DKI Jakarta', marker='o')
# Tambahkan garis atau plot untuk pasar lainnya
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Rawit')
plt.title('Tren Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Ambil data ke dalam Pandas DataFrame
data_pandas = data.toPandas()

# Plot menggunakan matplotlib dan seaborn
plt.figure(figsize=(12, 6))
plt.plot(data_pandas['Tanggal'], data_pandas['pasar glodok'], label='pasar glodok', marker='o')
# Tambahkan garis atau plot untuk pasar lainnya
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Rawit')
plt.title('Tren Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Ambil data ke dalam Pandas DataFrame
data_pandas = data.toPandas()

# Plot menggunakan matplotlib dan seaborn
plt.figure(figsize=(12, 6))
plt.plot(data_pandas['Tanggal'], data_pandas['pasar senen'], label='pasar senen', marker='o')
# Tambahkan garis atau plot untuk pasar lainnya
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Rawit')
plt.title('Tren Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Ambil data ke dalam Pandas DataFrame
data_pandas = data.toPandas()

# Plot menggunakan matplotlib dan seaborn
plt.figure(figsize=(12, 6))
plt.plot(data_pandas['Tanggal'], data_pandas['pasar Minggu'], label='pasar Minggu', marker='o')
# Tambahkan garis atau plot untuk pasar lainnya
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Rawit')
plt.title('Tren Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Ambil data ke dalam Pandas DataFrame
data_pandas = data.toPandas()

# Plot menggunakan matplotlib dan seaborn
plt.figure(figsize=(12, 6))
plt.plot(data_pandas['Tanggal'], data_pandas['Pasar kramat jati'], label='Pasar kramat jati', marker='o')
# Tambahkan garis atau plot untuk pasar lainnya
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Rawit')
plt.title('Tren Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Ambil data ke dalam Pandas DataFrame
data_pandas = data.toPandas()

# Plot menggunakan matplotlib dan seaborn
plt.figure(figsize=(12, 6))
plt.plot(data_pandas['Tanggal'], data_pandas['pasar Sunter Podomoro'], label='pasar Sunter Podomoro', marker='o')
# Tambahkan garis atau plot untuk pasar lainnya
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Rawit')
plt.title('Tren Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Plot menggunakan seaborn
plt.figure(figsize=(10, 6))
sns.histplot(data_pandas['DKI Jakarta'], bins=20, kde=True, color='blue', label='DKI Jakarta')
sns.histplot(data_pandas['pasar glodok'], bins=20, kde=True, color='orange', label='Pasar Glodok')
sns.histplot(data_pandas['pasar senen'], bins=20, kde=True, color='red', label='pasar senen')
sns.histplot(data_pandas['pasar Minggu'], bins=20, kde=True, color='yellow', label='pasar minggu')
sns.histplot(data_pandas['Pasar kramat jati'], bins=20, kde=True, color='green', label='pasar kramat jati')
sns.histplot(data_pandas['pasar Sunter Podomoro'], bins=20, kde=True, color='brown', label='pasar Sunter Podomoro')
# Tambahkan histogram atau KDE untuk pasar lainnya
plt.xlabel('Harga Cabai Rawit')
plt.ylabel('Frekuensi')
plt.title('Distribusi Harga Cabai Rawit di Berbagai Pasar')
plt.legend()
plt.show()

# %%
# Pilih kolom-kolom yang ingin dihitung korelasinya
selected_columns = ['DKI Jakarta', 'pasar glodok', 'pasar senen', 'pasar Minggu', 'Pasar kramat jati', 'pasar Sunter Podomoro']
correlation_matrix = data.select(selected_columns).toPandas().corr()

# Plot heatmap korelasi
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap Korelasi Harga Cabai Rawit di Berbagai Pasar')
plt.show()

# %%
# Pilih kolom-kolom yang ingin ditampilkan dalam boxplot
selected_columns = ['DKI Jakarta', 'pasar glodok', 'pasar senen', 'pasar Minggu', 'Pasar kramat jati', 'pasar Sunter Podomoro']
boxplot_data = data.select(selected_columns).toPandas()

# Plot boxplot
plt.figure(figsize=(12, 8))
sns.boxplot(data=boxplot_data)
plt.xlabel('Pasar')
plt.ylabel('Harga Cabai Rawit')
plt.title('Perbandingan Harga Cabai Rawit di Berbagai Pasar')
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import month
import matplotlib.pyplot as plt
import seaborn as sns

# Tambahkan kolom bulan
data = data.withColumn('Bulan', month('Tanggal'))

# Kelompokkan data berdasarkan bulan dan hitung rata-rata
monthly_data = data.groupBy('Bulan') \
                   .agg({'DKI Jakarta':'avg', 
                         'pasar glodok':'avg', 
                         'pasar senen':'avg', 
                         'pasar Minggu':'avg', 
                         'Pasar kramat jati':'avg', 
                         'pasar Sunter Podomoro':'avg'})

# Konversi DataFrame Spark menjadi Pandas DataFrame
pandas_monthly_data = monthly_data.toPandas()

# Plot heatmap menggunakan Matplotlib dan Seaborn
plt.figure(figsize=(12, 6))
sns.heatmap(pandas_monthly_data.set_index('Bulan'), cmap='YlGnBu', annot=True, fmt=".2f")
plt.xlabel('Pasar')
plt.ylabel('Bulan')
plt.title('Rata-rata Harga Cabai Rawit per Bulan di Berbagai Pasar')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(pandas_monthly_data.set_index('Bulan'), marker='o')
plt.xlabel("Bulan")
plt.ylabel("Rata-rata Harga")
plt.title("Visualisasi Musiman Harga Cabai Rawit")
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator

# %%
# Hapus baris dengan nilai NULL
df = data.dropna()

# Ubah kolom Tanggal ke dalam bentuk timestamp
df = df.withColumn("Tanggal", df["Tanggal"].cast("timestamp"))

# Gabungkan fitur-fitur yang ingin Anda gunakan dalam satu kolom vektor
feature_cols = ['DKI Jakarta', 'pasar glodok', 'pasar senen', 'pasar Minggu', 'Pasar kramat jati', 'pasar Sunter Podomoro']
assembler = VectorAssembler(inputCols=feature_cols, outputCol='features')
df = assembler.transform(df)

# %%
# Pisahkan data menjadi set pelatihan dan set pengujian
train_data, test_data = df.randomSplit([0.8, 0.2], seed=1234)

# Inisialisasi model regresi linear
lr = LinearRegression(featuresCol='features', labelCol='DKI Jakarta')

# Latih model
lr_model = lr.fit(train_data)

# %%
# Prediksi harga pada set pengujian
test_results = lr_model.transform(test_data)

# Evaluasi menggunakan RegressionEvaluator
evaluator = RegressionEvaluator(labelCol='DKI Jakarta', predictionCol='prediction', metricName='rmse')
rmse = evaluator.evaluate(test_results)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.18225e-11

# %%
# Evaluasi menggunakan RegressionEvaluator
evaluator = RegressionEvaluator(labelCol='DKI Jakarta', predictionCol='prediction')

# Menghitung MSE
mse = evaluator.evaluate(test_results, {evaluator.metricName: "mse"})
print("Mean Squared Error (MSE) on test data = %g" % mse)
# Out:
# Mean Squared Error (MSE) on test data = 4.76221e-22

# %%
# Menghitung MAE
mae = evaluator.evaluate(test_results, {evaluator.metricName: "mae"})
print("Mean Absolute Error (MAE) on test data = %g" % mae)
# Out:
# Mean Absolute Error (MAE) on test data = 1.71707e-11

# %%
# Menghitung R-squared (R2)
r2 = evaluator.evaluate(test_results, {evaluator.metricName: "r2"})
print("R-squared (R2) on test data = %g" % r2)
# Out:
# R-squared (R2) on test data = 1

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ambil hasil prediksi
prediction_and_actual = test_results.select("Tanggal", "DKI Jakarta").toPandas()

# Plot nilai sebenarnya dan nilai prediksi sepanjang waktu
plt.figure(figsize=(12, 6))
plt.plot(prediction_and_actual['Tanggal'], prediction_and_actual['DKI Jakarta'], label='Actual', marker='o')
plt.title('Actual Prices Over Time')
plt.xlabel('Tanggal')
plt.ylabel('Harga DKI Jakarta')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ambil hasil prediksi
prediction_and_actual = test_results.select("Tanggal", "prediction").toPandas()

# Plot nilai prediksi sepanjang waktu dengan warna oranye
plt.figure(figsize=(12, 6))
plt.plot(prediction_and_actual['Tanggal'], prediction_and_actual['prediction'], label='Prediction', marker='o', color='orange')
plt.title('Predicted Prices Over Time')
plt.xlabel('Tanggal')
plt.ylabel('Harga DKI Jakarta')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Ambil hasil prediksi dan konversi ke Pandas DataFrame untuk memudahkan visualisasi
lr_predictions_pd = lr_model.transform(test_data).select("Tanggal", "DKI Jakarta", "prediction").toPandas()

# Buat scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(lr_predictions_pd["DKI Jakarta"], lr_predictions_pd["prediction"], alpha=0.5, color='blue')
plt.title('Linear Regression: Actual vs. Predicted Prices')
plt.xlabel('Harga Aktual (DKI Jakarta)')
plt.ylabel('Harga Prediksi')
plt.show()

# %%
#menampilkan hasil perubahan
data.printSchema()
# Out:
# root
#  |-- Tanggal: date (nullable = true)
#  |-- DKI Jakarta: integer (nullable = true)
#  |-- pasar glodok: integer (nullable = true)
#  |-- pasar senen: integer (nullable = true)
#  |-- pasar Minggu: integer (nullable = true)
#  |-- Pasar kramat jati: integer (nullable = true)
#  |-- pasar Sunter Podomoro: integer (nullable = true)
#  |-- Bulan: integer (nullable = true)

# %%
# Prediksi harga satu bulan ke depan
new_data = spark.read.csv("cabai.csv", header=True, inferSchema=True)
new_data = assembler.transform(new_data)
predictions_new_data = lr_model.transform(new_data)

# %%
# Menampilkan beberapa baris teratas dari hasil prediksi
predictions_new_data.select("Tanggal", "DKI Jakarta", "prediction").show()

spark.stop()
# Out:
# +-----------+-----------+------------------+
# |    Tanggal|DKI Jakarta|        prediction|
# +-----------+-----------+------------------+
# | 1 Jan 2020|      34809| 34809.00000000002|
# | 2 Jan 2020|      34809| 34809.00000000002|
# | 3 Jan 2020|      34957| 34957.00000000002|
# | 4 Jan 2020|      36234| 36234.00000000002|
# | 5 Jan 2020|      37340|37340.000000000015|
# | 6 Jan 2020|      38574|           38574.0|
# | 7 Jan 2020|      39532|           39532.0|
# | 8 Jan 2020|      39255| 39255.00000000001|
# | 9 Jan 2020|      38957| 38957.00000000001|
# |10 Jan 2020|      39426| 39426.00000000001|
# |11 Jan 2020|      38851| 38851.00000000001|
# |12 Jan 2020|      39085|           39085.0|
# |13 Jan 2020|      38957|38957.000000000015|
# |14 Jan 2020|      39277|           39277.0|
# |15 Jan 2020|      40362|           40362.0|
# |16 Jan 2020|      40894|           40894.0|
# |17 Jan 2020|      41596| 41596.00000000001|
# |18 Jan 2020|      41809| 41809.00000000001|
# ...
